# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import libraries
import pandas as pd
import requests
import time
from datetime import datetime
import matplotlib.pyplot as plt

# Caches for geocoding and weather results
geocode_cache = {}
weather_cache = {}

# %%
def geocode_address(address, city=None):
    """
    Geocode an address using public Nominatim API, with caching.
    Returns (latitude, longitude) or (None, None) if failed.
    """
    query = f"{address}, {city}, Connecticut" if city else f"{address}, Connecticut"
    if query in geocode_cache:
        return geocode_cache[query]

    base_url = "https://nominatim.openstreetmap.org/search"
    params = {
        'q': query,
        'format': 'json',
        'limit': 1,
        'addressdetails': 1,
        'countrycodes': 'us'
    }
    headers = {
        'User-Agent': 'MyGeocodingTestApp/1.0 (student@lab6)'
    }

    try:
        response = requests.get(base_url, params=params, headers=headers)
        print(f"Status code for '{query}': {response.status_code}")
        if response.status_code == 200:
            data = response.json()
            if data:
                lat = float(data[0]['lat'])
                lon = float(data[0]['lon'])
                geocode_cache[query] = (lat, lon)
                return lat, lon
            else:
                print(f"No results for '{query}'")
                geocode_cache[query] = (None, None)
                return None, None
        else:
            print(f"Error for '{query}': {response.status_code}, {response.text}")
            geocode_cache[query] = (None, None)
            return None, None
    except requests.RequestException as e:
        print(f"Request failed for '{query}': {e}")
        geocode_cache[query] = (None, None)
        return None, None

    time.sleep(1)  # Respect Nominatim's 1 request/second limit

def fetch_weather(lat, lon, date):
    """
    Fetch max temperature (C) and precipitation (mm) for a date using Open Meteo Archive API.
    Returns (max_temp, precip) or (None, None) if failed.
    """
    if lat is None or lon is None:
        print(f"Skipping weather fetch: Invalid coordinates (lat={lat}, lon={lon})")
        return None, None

    cache_key = (round(lat, 4), round(lon, 4), date.strftime('%Y-%m-%d'))
    if cache_key in weather_cache:
        return weather_cache[cache_key]

    base_url = "https://archive-api.open-meteo.com/v1/archive"
    date_str = date.strftime('%Y-%m-%d')
    params = {
        'latitude': lat,
        'longitude': lon,
        'start_date': date_str,
        'end_date': date_str,
        'daily': 'temperature_2m_max,precipitation_sum',
        'timezone': 'America/New_York'
    }

    try:
        response = requests.get(base_url, params=params)
        print(f"Weather API status for lat={lat}, lon={lon}, date={date_str}: {response.status_code}")
        if response.status_code == 200:
            data = response.json()
            if 'daily' in data and data['daily']['temperature_2m_max'] and data['daily']['precipitation_sum']:
                max_temp = data['daily']['temperature_2m_max'][0]
                precip = data['daily']['precipitation_sum'][0]
                weather_cache[cache_key] = (max_temp, precip)
                return max_temp, precip
            else:
                print(f"No weather data for lat={lat}, lon={lon}, date={date_str}")
                weather_cache[cache_key] = (None, None)
                return None, None
        else:
            print(f"Weather API error: {response.status_code}, {response.text}")
            weather_cache[cache_key] = (None, None)
            return None, None
    except requests.RequestException as e:
        print(f"Weather request failed: {e}")
        weather_cache[cache_key] = (None, None)
        return None, None

    time.sleep(0.5)  # Conservative delay for Open Meteo

# %%
# Step 1: Load the dataset
csv_file = '/content/drive/MyDrive/Informatics-INFO8000/Data/real_estate.csv'
try:
    df = pd.read_csv(csv_file)
except FileNotFoundError:
    print(f"Error: File '{csv_file}' not found.")
    exit(1)
except pd.errors.EmptyDataError:
    print("Error: CSV file is empty.")
    exit(1)

'''# Verify required columns (based on Kaggle dataset)
required_columns = ['Address', 'Sale Date', 'Town']
if not all(col in df.columns for col in required_columns):
    print(f"Error: Missing required columns: {required_columns}")
    exit(1)'''

# Step 2: Filter for Mondays in April 2019
df['Date Recorded'] = pd.to_datetime(df['Date Recorded'], errors='coerce')
april_2019_mondays = df[
    (df['Date Recorded'].dt.year == 2019) &
    (df['Date Recorded'].dt.month == 4) &
    (df['Date Recorded'].dt.dayofweek == 0)
]

# Remove rows with missing Address
filtered_data = april_2019_mondays[april_2019_mondays['Address'].notna()].copy()

# Step 3: Geocode addresses missing latitude/longitude
if 'Latitude' not in filtered_data.columns:
    filtered_data['Latitude'] = pd.NA
if 'Longitude' not in filtered_data.columns:
    filtered_data['Longitude'] = pd.NA

for idx, row in filtered_data.iterrows():
    if pd.notna(row['Latitude']) and pd.notna(row['Longitude']):
        continue

    address = row['Address']
    #city = row.get('Town')
    lat, lon = geocode_address(address)
    filtered_data.at[idx, 'Latitude'] = lat
    filtered_data.at[idx, 'Longitude'] = lon

# Step 4: Drop rows with NaN latitude/longitude
geocoded_data = filtered_data.dropna(subset=['Latitude', 'Longitude']).copy()

# Step 5: Fetch weather data
geocoded_data['Max_Temperature_C'] = pd.NA
geocoded_data['Precipitation_mm'] = pd.NA

for idx, row in geocoded_data.iterrows():
    lat = row['Latitude']
    lon = row['Longitude']
    date = row['Date Recorded']
    max_temp, precip = fetch_weather(lat, lon, date)
    geocoded_data.at[idx, 'Max_Temperature_C'] = max_temp
    geocoded_data.at[idx, 'Precipitation_mm'] = precip

# Step 6: Save final enhanced dataset
final_file = 'enhanced_real_estate_april_2019.csv'
geocoded_data.to_csv(final_file, index=False)
print(f"Final enhanced dataset saved to '{final_file}'.")

# Display first few rows
print("\nFirst few rows of enhanced data:")
print(geocoded_data[['Address', 'Date Recorded', 'Town', 'Latitude', 'Longitude', 'Max_Temperature_C', 'Precipitation_mm']].head())

# Log failed geocoding
failed = filtered_data[filtered_data['Latitude'].isna()]['Address']
if not failed.empty:
    print("\nFailed addresses:", failed.tolist())
# Out:
# <ipython-input-17-e52fc26ddfb2>:4: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Status code for '12 LILAC LA, Connecticut': 200
# Status code for '626 MAIN ST, Connecticut': 200
# Status code for '331 LEDGE DR, Connecticut': 200
# Status code for '6 HICKORY LA, Connecticut': 200
# Status code for '44 OLD ELLINGTON RD, Connecticut': 200
# Status code for '242 MIDDLETOWN ROAD, Connecticut': 200
# Status code for '5 JUNIPER RD, Connecticut': 200
# Status code for '135, 137, 139 VALLEY DR, Connecticut': 200
# No results for '135, 137, 139 VALLEY DR, Connecticut'
# Status code for '69 BLACK ROCK AVE, Connecticut': 200
# Status code for '57-59 DIVINITY ST, Connecticut': 200
# Status code for '809 BIRMINGHAM CONDO, Connecticut': 200
# No results for '809 BIRMINGHAM CONDO, Connecticut'
# Status code for '118 GLENWOOD RD, Connecticut': 200
# Status code for '101 RIDGEDALE ROAD, Connecticut': 200
# Status code for '14 INDIAN WOODS RD, Connecticut': 200
# Status code for '61 COURT D APT 61 BLDG 28 SUCC, Connecticut': 200
# No results for '61 COURT D APT 61 BLDG 28 SUCC, Connecticut'
# Status code for '9 LAFAYETTE COURT, Connecticut': 200
# Status code for '30 IVY WAY, Connecticut': 200
# Status code for '3 BREEZY KNOLL DR, Connecticut': 200
# Status code for '29 JENNING STREET, Connecticut': 200
# No results for '29 JENNING STREET, Connecticut'
# Status code for '40 BASSETT ST, Connecticut': 200
# Status code for '118 LUCILLE STREET, Connecticut': 200
# Status code for '279 NO MAIN ST, Connecticut': 200
# Status code for '39 CAMBRIDGE ST, Connecticut': 200
# Status code for '135 PORTER STREET, Connecticut': 200
# Status code for '33 JENNY CLIFF, Connecticut': 200
# Status code for '8 WHITE PINE DR, Connecticut': 200
# Status code for '86 KINGS CT, Connecticut': 200
# Status code for '54 EMILY LANE, Connecticut': 200
# Status code for '112 ROOSEVELT ST, Connecticut': 200
# Status code for '210 JUDD ROAD, Connecticut': 200
# Status code for '10 FLORENCE AVE, Connecticut': 200
# Status code for '160 WARDE TERRACE, Connecticut': 200
# Status code for '19 PINEWOODS LA, Connecticut': 200
# No results for '19 PINEWOODS LA, Connecticut'
# Status code for '9 HILLSIDE AVE, Connecticut': 200
# Status code for '73 RASPBERRY HILL, Connecticut': 200
# No results for '73 RASPBERRY HILL, Connecticut'
# Status code for '74 ABBE RD, Connecticut': 200
# Status code for '140 THOMPSON ST #17D, Connecticut': 200
# Status code for '81 GLEN RIDGE CT, Connecticut': 200
# Status code for '170 SO MAIN ST, Connecticut': 200
# No results for '170 SO MAIN ST, Connecticut'
# Status code for '90 EL TORO DR, Connecticut': 200
# Status code for '33 WALKER LN, Connecticut': 200
# Status code for '22 ARDMORE ROAD, Connecticut': 200
# Status code for '17 ROBIN HILL ROAD, Connecticut': 200
# Status code for '11 KEVIN DR, Connecticut': 200
# Status code for '100 CROSS DR, Connecticut': 200
# Status code for '23 SURREY LA, Connecticut': 200
# Status code for '332 ALLEN HILL RD, Connecticut': 200
# Status code for '37 BRIARWOOD LN, Connecticut': 200
# Status code for '35 DEER RUN RD, Connecticut': 200
# Status code for '220 TESINY AVE, Connecticut': 200
# Status code for '94 & 98 BEAVER BROOK RD, Connecticut': 200
# Status code for '136 WOODYCREST DR, Connecticut': 200
# Status code for '20 MELROSE ST, Connecticut': 200
# Status code for '42 HOBSON AVE, Connecticut': 200
# Status code for '85 PINEHURST RD, Connecticut': 200
# Status code for '604 MINE HILL ROAD, Connecticut': 200
# Status code for '114 NEWENT ROAD, Connecticut': 200
# Status code for '55 CABOT ST, Connecticut': 200
# Status code for '203 RIDGEWOOD AVE, Connecticut': 200
# Status code for '107 KELSEYTOWN RD, Connecticut': 200
# Status code for 'BUILDING 51 APT 401 OF SUCCESS, Connecticut': 200
# No results for 'BUILDING 51 APT 401 OF SUCCESS, Connecticut'
# Status code for '660 WILLIAM ST, Connecticut': 200
# Status code for '52 ALEXANDER DR, Connecticut': 200
# Status code for '173-175 GOLDENROD AVE, Connecticut': 200
# Status code for '165 FOXBRIDGE VILLAGE, Connecticut': 200
# Status code for '27 GRISWOLD RD, Connecticut': 200
# Status code for '10 LOVELAND ST, Connecticut': 200
# Status code for '184 OBERLIN RD, Connecticut': 200
# Status code for '53 WOODHOUSE AVE, Connecticut': 200
# Status code for 'CHAMBERLAIN HWY; 14-1/12/13, Connecticut': 200
# No results for 'CHAMBERLAIN HWY; 14-1/12/13, Connecticut'
# Status code for '63 PEARL HARBOR, Connecticut': 200
# Status code for '150 CENTRAL AVE, Connecticut': 200
# Status code for '415 EAST RD, Connecticut': 200
# Status code for '120 WILLARD DR, Connecticut': 200
# Status code for '271 SEASIDE AVE, Connecticut': 200
# Status code for '32 SUNDANCE, Connecticut': 200
# Status code for '22 WEST RD, Connecticut': 200
# Status code for '28 MATHIEU LANE, Connecticut': 200
# Status code for '132 ALDINE AVE, Connecticut': 200
# Status code for '44 CHERRY ST, Connecticut': 200
# Status code for '192-194 HIGH STREET, Connecticut': 200
# Status code for '31 BENZ ST, Connecticut': 200
# Status code for '4 DEAN RD, Connecticut': 200
# Status code for '133 WESTERLY TER, Connecticut': 200
# Status code for '611 WOLCOTT RD, Connecticut': 200
# Status code for '34 WASHINGTON DR, Connecticut': 200
# Status code for '41 SULLIVAN FARM, Connecticut': 200
# Status code for '25 COW PEN HILL ROAD, Connecticut': 200
# Status code for '7 NEW YORK RD, Connecticut': 200
# Status code for '7 GLEN DR, Connecticut': 200
# Status code for '37 LENOX AVE, Connecticut': 200
# Status code for '1207 CHOPSEY HILL RD, Connecticut': 200
# Status code for '201 EXETER ST, Connecticut': 200
# Status code for '107 BURBAN DR, Connecticut': 200
# Status code for '125 OLIVE ST #E-1, Connecticut': 200
# No results for '125 OLIVE ST #E-1, Connecticut'
# Status code for '2016 NORTH AVE, Connecticut': 200
# Status code for '22 GLEN RDIGE CT, Connecticut': 200
# No results for '22 GLEN RDIGE CT, Connecticut'
# Status code for '11 ESSEX RD, Connecticut': 200
# Status code for '80 STUART RD EAST, Connecticut': 200
# Status code for '3380 MADISON AVE UNIT 15A, Connecticut': 200
# No results for '3380 MADISON AVE UNIT 15A, Connecticut'
# Status code for '6 EMMA RD, Connecticut': 200
# Status code for '208 REMINGTON ST, Connecticut': 200
# Status code for '91 RIVERVIEW RD  #8C, Connecticut': 200
# No results for '91 RIVERVIEW RD  #8C, Connecticut'
# Status code for '91 WHEELING RD, Connecticut': 200
# Status code for '11 RACEBROOK DRIVE, Connecticut': 200
# Status code for '40 OWEN ST #C-11, D-02, E-2, E, Connecticut': 200
# No results for '40 OWEN ST #C-11, D-02, E-2, E, Connecticut'
# Status code for '24 COLONY ST, Connecticut': 200
# Status code for 'CHAMBERLAIN HWY; 13-2/12/10, Connecticut': 200
# No results for 'CHAMBERLAIN HWY; 13-2/12/10, Connecticut'
# Status code for '105 ROOSEVELT DR, Connecticut': 200
# Status code for '91 E PATTAGANSETT RD, Connecticut': 200
# Status code for '26 YANKEE HILL RD, Connecticut': 200
# Status code for '196 CHURCH ST, Connecticut': 200
# Status code for '5 COACHMAN PIKE', Connecticut': 200
# Status code for '8 RIDGE RD, Connecticut': 200
# Status code for '20 ORBIT DR, Connecticut': 200
# Status code for '104 PRESTON ALLEN ROAD, Connecticut': 200
# Status code for '135 OAK ST, Connecticut': 200
# Status code for '1 MAPLE ST #25, Connecticut': 200
# No results for '1 MAPLE ST #25, Connecticut'
# Status code for '61 SILLIMAN STREET, Connecticut': 200
# Status code for '245 OLD FORGE RD, Connecticut': 200
# Status code for '86 INDIANTOWN RD, Connecticut': 200
# Status code for '41 WINDHAM ST, Connecticut': 200
# Status code for '230 ROBIN LANE, Connecticut': 200
# Status code for '467 LEXINGTON AVE, Connecticut': 200
# Status code for '133 ORCHARD ST, Connecticut': 200
# Status code for '18 STONECLIFFE DR, Connecticut': 200
# No results for '18 STONECLIFFE DR, Connecticut'
# Status code for '4 OLD KING ST, Connecticut': 200
# Status code for '128 RESERVIOR AVE, Connecticut': 200
# No results for '128 RESERVIOR AVE, Connecticut'
# Status code for '749 CHAMBERLAIN HWY, Connecticut': 200
# Status code for '1 ROCK RIDGE CT, Connecticut': 200
# Status code for '78 WESTWOOD RD, Connecticut': 200
# Status code for '24 WEST ELM ST 24, Connecticut': 200
# No results for '24 WEST ELM ST 24, Connecticut'
# Status code for '3 PRINCETON LN, Connecticut': 200
# Status code for '281 DODGE AVE, Connecticut': 200
# Status code for '82 NORTH ST, Connecticut': 200
# Status code for '105 OLD FARM RD, Connecticut': 200
# Status code for '42 RIDGE RD, Connecticut': 200
# Status code for '150 ADAMS ST, Connecticut': 200
# Status code for '167 RICHMOND RD, Connecticut': 200
# Status code for '36-38 BROADWAY AVE, Connecticut': 200
# Status code for '91 FEDERAL ST, Connecticut': 200
# Status code for '194 OAK RIDGE LN, Connecticut': 200
# Status code for '116 BRADLEY ST, Connecticut': 200
# Status code for '45 POCONO LANE #10, Connecticut': 200
# No results for '45 POCONO LANE #10, Connecticut'
# Status code for 'UNIT C-12 RIVER ROAD, Connecticut': 200
# No results for 'UNIT C-12 RIVER ROAD, Connecticut'
# Status code for '77 DARBY ST, Connecticut': 200
# Status code for '38 KNOLLWOOD RD, Connecticut': 200
# Status code for '42 CHESTNUT COURT U-48G, Connecticut': 200
# No results for '42 CHESTNUT COURT U-48G, Connecticut'
# Status code for '222 WILLIAMS ST E UNIT 406, Connecticut': 200
# No results for '222 WILLIAMS ST E UNIT 406, Connecticut'
# Status code for '81 EASTWOOD RD, Connecticut': 200
# Status code for '675 TOWNSEND AV #144, Connecticut': 200
# Status code for '222 ROBBINS AVE, Connecticut': 200
# Status code for '61 HOPE ST, Connecticut': 200
# Status code for '67 OLD LANTERN RD, Connecticut': 200
# Status code for '3 CEDAR MEADOW RD, Connecticut': 200
# Status code for '228 WEST ELM ST, Connecticut': 200
# Status code for '45 HARVESTER ROAD, Connecticut': 200
# Status code for '83 FIELDSTONE LANE, Connecticut': 200
# Status code for '3 MARY LANE, Connecticut': 200
# Status code for 'WALLINGFORD RD, Connecticut': 200
# Status code for '288 MCKINLEY AV, Connecticut': 200
# Status code for '37 BILYEU ROAD, Connecticut': 200
# Status code for '70 SKY TOP TERRACE, Connecticut': 200
# Status code for '58 CHARIS ROAD, Connecticut': 200
# Status code for '10 CHARLES LA, Connecticut': 200
# Status code for '47 TATNIC HILL RD, Connecticut': 200
# Status code for 'PLAYHOUSE CORNER #204, Connecticut': 200
# Status code for '57 MARLBOROUGH TERRACE, Connecticut': 200
# Status code for '229 ELLINGTON RD UNIT V, Connecticut': 200
# No results for '229 ELLINGTON RD UNIT V, Connecticut'
# Status code for '30 WOODHAVEN DRIVE, Connecticut': 200
# Status code for '26 BODWELL RD, Connecticut': 200
# Status code for '9 STAR FARMS DRIVE, Connecticut': 200
# Status code for '39 OLD POINT RD, Connecticut': 200
# Status code for '233 MOUNTAIN RD, Connecticut': 200
# Status code for '118 CANDLEWOOD DR, Connecticut': 200
# Status code for '614 BISHOP AVE, Connecticut': 200
# Status code for '292 MADISON AVE, Connecticut': 200
# Status code for '21 BROAD ST EXT, Connecticut': 200
# No results for '21 BROAD ST EXT, Connecticut'
# Status code for '136 TATER HILL RD, Connecticut': 200
# Status code for '248 MORNINGSIDE DR EAST, Connecticut': 200
# Status code for '109 LOUISIANA AVE, Connecticut': 200
# Status code for '130 WATCH HILL RD, Connecticut': 200
# Status code for '170-D BRITTANY FARMS, Connecticut': 200
# Status code for '10 WELLS RD, Connecticut': 200
# Status code for '133 CHAMBERLAIN HWY, Connecticut': 200
# Status code for '102 HENDERSON ST, Connecticut': 200
# Status code for '9 LYON RD, Connecticut': 200
# Status code for '883 WHALLEY AV, Connecticut': 200
# Status code for '3 GEM DR, Connecticut': 200
# Status code for '143 SANTA FE AVE, Connecticut': 200
# Status code for '45 WINTON RD, Connecticut': 200
# Status code for '648 WOLCOTT RD, Connecticut': 200
# Status code for '8 PACKARD STREET, Connecticut': 200
# Status code for '243 COUNTRY CLUB RD, Connecticut': 200
# Status code for '107 BARTLETT HOLLOW RD, Connecticut': 200
# Status code for '195 SEELEY ST, Connecticut': 200
# Status code for '226 FAIRWAY DR, Connecticut': 200
# Status code for '138 GEORGETOWN RD, Connecticut': 200
# Status code for '122 COALPIT HILL RD, Connecticut': 200
# No results for '122 COALPIT HILL RD, Connecticut'
# Status code for '185 TRAVIS DR, Connecticut': 200
# Status code for '20 VILLAGE CROSSING, Connecticut': 200
# No results for '20 VILLAGE CROSSING, Connecticut'
# Status code for '152 ROCKWELL RD A-1, Connecticut': 200
# No results for '152 ROCKWELL RD A-1, Connecticut'
# Status code for '119 SNIPSIC LAKE RD, Connecticut': 200
# Status code for '12 FRANCES HUNTER DR, Connecticut': 200
# Status code for '21 BOYLE DR, Connecticut': 200
# Status code for '3225 MADISON AVE UNIT 13, Connecticut': 200
# No results for '3225 MADISON AVE UNIT 13, Connecticut'
# Status code for '62 OMELIA RD, Connecticut': 200
# Status code for '162 BRITT RD, Connecticut': 200
# Status code for '131 COLLINS RD, Connecticut': 200
# Status code for '358 PERCIVAL AVENUE, Connecticut': 200
# Status code for '46 RIVER WALK, Connecticut': 200
# Status code for '965-D WILLIAM ST, Connecticut': 200
# Status code for '1 POSSUM RIDGE ROAD, Connecticut': 200
# Status code for '112 FAIRHAVEN DR, Connecticut': 200
# Status code for '30 PALISADE TER, Connecticut': 200
# Status code for '35 PRINCETON STREET, Connecticut': 200
# Status code for '565 NEWFIELD ST #25, Connecticut': 200
# Status code for '129 ASHTON ST, Connecticut': 200
# Status code for '6 STURDEVANT DR, Connecticut': 200
# Status code for '114 COLONY, Connecticut': 200
# Status code for '10 WILLOW SPRINGS, Connecticut': 200
# No results for '10 WILLOW SPRINGS, Connecticut'
# Status code for '169 MASON ST 2D, Connecticut': 200
# No results for '169 MASON ST 2D, Connecticut'
# Status code for '463 POOL RD, Connecticut': 200
# Status code for '34 CLARK HILL RD, Connecticut': 200
# Status code for '7 WELLINGTON CT DR, Connecticut': 200
# Status code for '43 COLONY ST, Connecticut': 200
# Status code for '9 MARLDON RD, Connecticut': 200
# No results for '9 MARLDON RD, Connecticut'
# Status code for '305-307 PRISCILLA ST, Connecticut': 200
# Status code for '76 QUINEBAUG CAMP RD LOT 8, Connecticut': 200
# No results for '76 QUINEBAUG CAMP RD LOT 8, Connecticut'
# Status code for '85 HENRY STREET, Connecticut': 200
# Status code for 'MAPLE AVE MP37 LT 15, Connecticut': 200
# No results for 'MAPLE AVE MP37 LT 15, Connecticut'
# Status code for '57 PARK ST, Connecticut': 200
# Status code for '188 CHESHIRE RD, Connecticut': 200
# Status code for '1 UPLANDS WAY, Connecticut': 200
# Status code for '80 PEDDLARS DR, Connecticut': 200
# No results for '80 PEDDLARS DR, Connecticut'
# Status code for '56 FRANKLIN ST #2-7, Connecticut': 200
# No results for '56 FRANKLIN ST #2-7, Connecticut'
# Status code for '6A MAPLEWOOD CONDO, Connecticut': 200
# No results for '6A MAPLEWOOD CONDO, Connecticut'
# Status code for '206 CHESTER ST, Connecticut': 200
# Status code for '41 BURTON ST, Connecticut': 200
# Status code for '5C HARBOUR VILLAGE, Connecticut': 200
# No results for '5C HARBOUR VILLAGE, Connecticut'
# Status code for '66 EMMETT ST UN 34, Connecticut': 200
# Status code for '50 LAFAYETTE PL 2F, Connecticut': 200
# No results for '50 LAFAYETTE PL 2F, Connecticut'
# Status code for '19 ROCKWOOD LANE SPUR, Connecticut': 200
# Status code for '38 WEST END AVE, Connecticut': 200
# Status code for '82 BENNETT POND RD, Connecticut': 200
# Status code for '103 MAPLE AVE, Connecticut': 200
# Status code for '308 MEADOWSIDE RD #210, Connecticut': 200
# Status code for '152 DEACON ST, Connecticut': 200
# Status code for '6 KENDALL TERR E, Connecticut': 200
# Status code for '37 BAUSOLA RD, Connecticut': 200
# Status code for '128 NORTH MAIN ST, Connecticut': 200
# Status code for '150 OLD STAGECOACH RD, Connecticut': 200
# Status code for '252 TRUMBULL AVE, Connecticut': 200
# Status code for '20 WESLEYAN TERR, Connecticut': 200
# Status code for '333 VINCELLETTE ST UNIT 1, Connecticut': 200
# No results for '333 VINCELLETTE ST UNIT 1, Connecticut'
# Status code for '26 BELMONT AVE, Connecticut': 200
# Status code for '60 WHITTLE ST, Connecticut': 200
# Status code for '29 BIRMINGHAM CT, Connecticut': 200
# Status code for '21 BURGUNDY DRIVE, Connecticut': 200
# Status code for '139 LINCOLN ST, Connecticut': 200
# Status code for '8690 POND ST, Connecticut': 200
# Status code for '117 CHESTNUT ST, Connecticut': 200
# Status code for '142 EAST SHORE RD, Connecticut': 200
# Status code for '32-34 HAZELWOOD ROAD, Connecticut': 200
# Status code for '1725 GLASGO RD, Connecticut': 200
# Status code for '34 SONGBIRD LA, Connecticut': 200
# Status code for '233 TYLER ST, Connecticut': 200
# Status code for '22 HEARTHSTONE DR, Connecticut': 200
# Status code for '48 LENOX AVE, Connecticut': 200
# Status code for '26 RUDOLPH RD, Connecticut': 200
# Status code for '99 WEBER AVE, Connecticut': 200
# Status code for '27 CHAPMAN ST, Connecticut': 200
# Status code for '152 COMSTOCK TRAIL, Connecticut': 200
# Status code for '661 SYLVAN AVE, Connecticut': 200
# Status code for '3 STEVENS ST, Connecticut': 200
# Status code for '32 CLEVELAND ST, Connecticut': 200
# Status code for '1175 WHITNEY AVE UB-1, Connecticut': 200
# No results for '1175 WHITNEY AVE UB-1, Connecticut'
# Status code for '22 BURNHAM ST, Connecticut': 200
# Status code for '41 CARNOUSTIE CIR, Connecticut': 200
# No results for '41 CARNOUSTIE CIR, Connecticut'
# Status code for '22A LIMEWOOD AVE, Connecticut': 200
# Status code for '155 WATCH HILL RD, Connecticut': 200
# Status code for '1 CARAFA TERR, Connecticut': 200
# Status code for '87 OCONNELL RD EXT, Connecticut': 200
# No results for '87 OCONNELL RD EXT, Connecticut'
# Status code for '32 ESTHER LN, Connecticut': 200
# Status code for '11 VAN HORN DR, Connecticut': 200
# Status code for '3 BERKSHIRE RD, Connecticut': 200
# Status code for '5 HONEY HOLLOW ROAD, Connecticut': 200
# Status code for '20 BLUE HILLS RD, Connecticut': 200
# Status code for '10 HEMINGWAY RD, Connecticut': 200
# Status code for '135 SQUIRREL TR, Connecticut': 200
# No results for '135 SQUIRREL TR, Connecticut'
# Status code for '11 BALSAM ST, Connecticut': 200
# Status code for 'R003 NEWBERRY RD, Connecticut': 200
# No results for 'R003 NEWBERRY RD, Connecticut'
# Status code for '5 STANDISH RD, Connecticut': 200
# Status code for '29 VICTORIA DR, Connecticut': 200
# Status code for '102 COMSTOCK TR, Connecticut': 200
# No results for '102 COMSTOCK TR, Connecticut'
# Status code for '150 WOODROW AVE, Connecticut': 200
# Status code for '520 VINCELLETTE ST UNIT D-1, Connecticut': 200
# No results for '520 VINCELLETTE ST UNIT D-1, Connecticut'
# Status code for '38 GEARY AVE, Connecticut': 200
# Status code for '29 TOWNE DRIVE, Connecticut': 200
# Status code for '305 EH MOODUS RD, Connecticut': 200
# No results for '305 EH MOODUS RD, Connecticut'
# Status code for '178 GOOSENECK HILL RD, Connecticut': 200
# Status code for '20 BANFIELD LN, Connecticut': 200
# Status code for '40 HAWTHORN RD, Connecticut': 200
# Status code for '110 MCKEE ST, Connecticut': 200
# Status code for '32 DAMON HEIGHTS RD, Connecticut': 200
# Status code for '61 BROOKVIEW CT, Connecticut': 200
# Status code for '41 GINA ST, Connecticut': 200
# Status code for '53 WOODBRIDGE RD, Connecticut': 200
# Status code for '295 REDSTONE HILL RD UN29, Connecticut': 200
# Status code for '574 KOSSUTH ST, Connecticut': 200
# Status code for '34 PEDDLARS DR, Connecticut': 200
# No results for '34 PEDDLARS DR, Connecticut'
# Status code for '220 ARNOLD DR, Connecticut': 200
# Status code for '18 INTERVALE RD, Connecticut': 200
# Status code for '51 PRESCOTT ST, Connecticut': 200
# Status code for '100 POND CIR, Connecticut': 200
# Status code for '40-42 WASHINGTON TER, Connecticut': 200
# Status code for '300 PECK ST, Connecticut': 200
# Status code for '45 MISTY MOUNTAIN ROAD, Connecticut': 200
# Status code for '177 TATNIC RD, Connecticut': 200
# Status code for '63 WOODBRIDGE RD, Connecticut': 200
# Status code for '495 HAWLEY AVE, Connecticut': 200
# Status code for '36 WHITING FARM RD, Connecticut': 200
# Status code for '117 JACKSON RD, Connecticut': 200
# Status code for '171 PLAINS RD, Connecticut': 200
# Status code for '64 THIMBLE ISLANDS RD, Connecticut': 200
# Status code for '16 RED BRICK LN, Connecticut': 200
# Status code for '74 CONSTANCE DRIVE, Connecticut': 200
# Status code for '14 GREAT HILL DRIVE, Connecticut': 200
# Status code for '83 SPRUCE ST, Connecticut': 200
# Status code for '1 HIRAM LN, Connecticut': 200
# Status code for '270 CASTLEWOOD DR, Connecticut': 200
# Status code for '172 HARBOR AVE, Connecticut': 200
# Status code for '22 ROBINDALE DRIVE, Connecticut': 200
# Status code for '43 MASSACHUSETTS AVE, Connecticut': 200
# Status code for '18 VAN TASSELL DR, Connecticut': 200
# No results for '18 VAN TASSELL DR, Connecticut'
# Status code for '160 WOODLAND ST, Connecticut': 200
# Status code for '182 HUNTERS LN, Connecticut': 200
# Status code for '267 FERN HILL RD, Connecticut': 200
# Status code for '287 JACKSON AVE, Connecticut': 200
# Status code for '13 JACKSON ST, Connecticut': 200
# Status code for 'MARSHALL LN, Connecticut': 200
# Status code for '15 CLARK ST, Connecticut': 200
# Status code for '50 PROSPECT HILL DR, Connecticut': 200
# Status code for '26 BANBURY LN, Connecticut': 200
# Status code for '260 SONTROM RD, Connecticut': 200
# No results for '260 SONTROM RD, Connecticut'
# Status code for '103 DEER RUN RD, Connecticut': 200
# Status code for '94 STONEHOUSE RD #17, Connecticut': 200
# Status code for '87 COWLES ST, Connecticut': 200
# Status code for '18 LEDGE RD, Connecticut': 200
# Status code for '14 AMES AVE, Connecticut': 200
# Status code for '560 NORTH WASHINGTON AVE #06H, Connecticut': 200
# No results for '560 NORTH WASHINGTON AVE #06H, Connecticut'
# Status code for '43 MILLS LN, Connecticut': 200
# Status code for '24 RIVER VIEW DR, Connecticut': 200
# Status code for '190 NORTH ELM STREET, Connecticut': 200
# Status code for '48 PLATTS HILL ROAD, Connecticut': 200
# Status code for '26 TRUMBULL RD, Connecticut': 200
# Status code for '278 SKYVIEW DR U V-6, Connecticut': 200
# No results for '278 SKYVIEW DR U V-6, Connecticut'
# Status code for '157 NEWGATE ROAD, Connecticut': 200
# Status code for 'SATANS KINGDOM ROAD, Connecticut': 200
# No results for 'SATANS KINGDOM ROAD, Connecticut'
# Status code for '1 ABBOTT RD #3, Connecticut': 200
# No results for '1 ABBOTT RD #3, Connecticut'
# Status code for '34 HAZELMEADOW PLACE, Connecticut': 200
# Status code for '290 CHESTERFIELD RD, Connecticut': 200
# Status code for '12 PILGRIM ROAD, Connecticut': 200
# Status code for '70 RIVERSIDE DR #A13, Connecticut': 200
# No results for '70 RIVERSIDE DR #A13, Connecticut'
# Status code for '429 TUNNEL RD, Connecticut': 200
# Status code for '380 FOREST ST, Connecticut': 200
# Status code for '25 FRARY AVE, Connecticut': 200
# Status code for '18 GLENWOOD ST, Connecticut': 200
# Status code for '138 MILLSTREAM RD, Connecticut': 200
# Status code for '192 BOULEY AVE, Connecticut': 200
# Status code for '159 ZION ST, Connecticut': 200
# Status code for '12A ALGONQUIN LN, Connecticut': 200
# Status code for '107 BRACE ROAD, Connecticut': 200
# Status code for '188 WARREN ST, Connecticut': 200
# Status code for '25 PRIVATE RD, Connecticut': 200
# Status code for '66 OAKLAND RD, Connecticut': 200
# Status code for '85 UPLANDS WAY, Connecticut': 200
# Status code for '135 CITY AVE, Connecticut': 200
# Status code for '19 NATSISKY FARM RD, Connecticut': 200
# Status code for '253 STONEHOUSE RD, Connecticut': 200
# Status code for '50 DURWIN ST, Connecticut': 200
# Status code for '11 ROSEMONT DT, Connecticut': 200
# No results for '11 ROSEMONT DT, Connecticut'
# Status code for '34 ALDRICH AVE, Connecticut': 200
# Status code for '13 OVERVALE RD, Connecticut': 200
# Status code for '124 STAFFORD RD, Connecticut': 200
# Status code for '27 FIFTH AVE, Connecticut': 200
# Status code for '482 E HERITAGE VILLAGE, Connecticut': 200
# Status code for '65 DOGWOOD RD, Connecticut': 200
# Status code for '26 QUEEN ST, Connecticut': 200
# Status code for '60 PENNY LN, Connecticut': 200
# Status code for '8 HOLLISTER DRIVE, Connecticut': 200
# Status code for '49 PINEHURST DR, Connecticut': 200
# Status code for '835 LONG HILL RD #B, Connecticut': 200
# No results for '835 LONG HILL RD #B, Connecticut'
# Status code for '0 QUINEBAUG RD, Connecticut': 200
# Status code for '33 JOHN ST, Connecticut': 200
# Status code for '304 WOODLAND HILLS DRIVE, Connecticut': 200
# Status code for '96 PROSPECT AVE, Connecticut': 200
# Status code for '35 FLORENCE ST, Connecticut': 200
# Status code for '21 JOHN DRIVE, Connecticut': 200
# Status code for '38 JESSAMINE STREET, Connecticut': 200
# Status code for '21 SHERMAN DR, Connecticut': 200
# Status code for '287 HELL HOLLOW RD, Connecticut': 200
# Status code for '15 CHESTNUT COURT U-30A, Connecticut': 200
# No results for '15 CHESTNUT COURT U-30A, Connecticut'
# Status code for '154 KINGS HWY UNIT C, Connecticut': 200
# No results for '154 KINGS HWY UNIT C, Connecticut'
# Status code for '293 COUNTRY CLUB RD, Connecticut': 200
# Status code for '23 AKRON ST, Connecticut': 200
# Status code for '6 WEST MAIN ST, Connecticut': 200
# Status code for '657 S MAIN ST, Connecticut': 200
# Status code for '11 HARBOR RIDGE RD, Connecticut': 200
# Status code for '95 WESTWOOD AVE, Connecticut': 200
# Status code for '75 MEADOW ST, Connecticut': 200
# Status code for '62 LAUREL LANE, Connecticut': 200
# Status code for '893 FARMINGTON AVENUE UNIT 2-2, Connecticut': 200
# No results for '893 FARMINGTON AVENUE UNIT 2-2, Connecticut'
# Status code for '35-37 PEACE ST, Connecticut': 200
# Status code for '74 ARNOLD DRIVE, Connecticut': 200
# Status code for '6 EVERGREEN, Connecticut': 200
# Status code for '356 FROST RD, Connecticut': 200
# Status code for '54 ROPE FERRY RD B24 & GAR16, Connecticut': 200
# No results for '54 ROPE FERRY RD B24 & GAR16, Connecticut'
# Status code for '330 MERWIN AVE #5E, Connecticut': 200
# No results for '330 MERWIN AVE #5E, Connecticut'
# Status code for '135 WARNER RD, Connecticut': 200
# Status code for '14 CURTIS AVE, Connecticut': 200
# Status code for '50 FAIRFAX AVE, Connecticut': 200
# Status code for '60 HARBORSIDE DR, Connecticut': 200
# Status code for '543 ROPE FERRY RD  D67, Connecticut': 200
# No results for '543 ROPE FERRY RD  D67, Connecticut'
# Status code for '28 GILFORD STREET, Connecticut': 200
# Status code for '14 ROCKY HILL RD, Connecticut': 200
# Status code for '24 CHAPMAN ST, Connecticut': 200
# Status code for '106 NEWTON ST, Connecticut': 200
# Status code for '126 LYDALL STREET, Connecticut': 200
# Status code for '19 FLORENCE STREET, Connecticut': 200
# Status code for '95 MULBERRY ST, Connecticut': 200
# Status code for '56 LORINGS, Connecticut': 200
# No results for '56 LORINGS, Connecticut'
# Status code for '8A 8B 8A-A1 PASCO DR, Connecticut': 200
# No results for '8A 8B 8A-A1 PASCO DR, Connecticut'
# Status code for '156 AMSTON RD, Connecticut': 200
# Status code for '66 BOSTWICK STREET, Connecticut': 200
# Status code for '85 CANARY PL, Connecticut': 200
# Status code for '331 MERROW ROAD, Connecticut': 200
# Status code for '40 SAVIN PARK, Connecticut': 200
# Status code for '4 PEQUOT RUN, Connecticut': 200
# Status code for '38 WILLIAMS STREET, Connecticut': 200
# Status code for '12 GREEN ACRE LANE, Connecticut': 200
# Status code for '91 STRAWBERRY HILL AVE # 1138, Connecticut': 200
# Status code for '73 PARSONS DRIVE, Connecticut': 200
# Status code for '26 RIVER HIGHLANDS DR, Connecticut': 200
# Status code for '51 MELTON DR, Connecticut': 200
# Status code for '128 JEFFREY LN, Connecticut': 200
# Status code for '38-40 WOODLAWN STREET, Connecticut': 200
# Status code for 'LOT 1 EDEN ROAD, Connecticut': 200
# Status code for '80 COUNTRY LN #41, Connecticut': 200
# Status code for '42 ALLENTOWN RD, Connecticut': 200
# Status code for '34 CRESCENT STREET # 1F, Connecticut': 200
# No results for '34 CRESCENT STREET # 1F, Connecticut'
# Status code for '7 DEAN ST #1-103, Connecticut': 200
# No results for '7 DEAN ST #1-103, Connecticut'
# Status code for '92 MAIN ST # 105, Connecticut': 200
# Status code for '530 GAYLORD MTN RD, Connecticut': 200
# Status code for '565 NEW HARWINTON RD, Connecticut': 200
# Status code for '39 CALVIN FRECH RD, Connecticut': 200
# No results for '39 CALVIN FRECH RD, Connecticut'
# Status code for '67 EDWARD RD, Connecticut': 200
# Status code for '152 ROCKWELL RD A-2, Connecticut': 200
# No results for '152 ROCKWELL RD A-2, Connecticut'
# Status code for '4 BLUE RIBBON DRIVE, Connecticut': 200
# Status code for '421 ATLANTIC STREET # ASCAI-3, Connecticut': 200
# No results for '421 ATLANTIC STREET # ASCAI-3, Connecticut'
# Status code for '183 MARLBOROUGH TERRACE, Connecticut': 200
# Status code for '12 LIVEMORE TRAIL, Connecticut': 200
# Status code for '26 MANOR RD, Connecticut': 200
# Status code for '110 SILVERSMITH DR, Connecticut': 200
# Status code for '694 BRIGHAM TAVERN RD, Connecticut': 200
# Status code for '20 WENDY LANE, Connecticut': 200
# Status code for '6 GLEN RD, Connecticut': 200
# Status code for '113 EDDON DR, Connecticut': 200
# Status code for '4 ECHO DR, Connecticut': 200
# Status code for '12 WEST RIVER RD, Connecticut': 200
# Status code for '216 LAKEWOOD RD, Connecticut': 200
# Status code for '15 PEASLEE HILL, Connecticut': 200
# Status code for '115 WATERBURY AVENUE, Connecticut': 200
# Status code for '33 DELMAR RD, Connecticut': 200
# Status code for '44 STRAWBERRY HILL AVE # 12B, Connecticut': 200
# No results for '44 STRAWBERRY HILL AVE # 12B, Connecticut'
# Status code for '4 ELM ROAD, Connecticut': 200
# Status code for '177 STARKS HILL RD, Connecticut': 200
# Status code for '74 FORSYTH RD, Connecticut': 200
# Status code for '15 MOUNTFORD ST, Connecticut': 200
# Status code for '32 WALKER LANE, Connecticut': 200
# Status code for '966 RT 171, Connecticut': 200
# Status code for '28 CEDAR ISLAND AVE, Connecticut': 200
# Status code for '39 SUMMERWOOD DR, Connecticut': 200
# No results for '39 SUMMERWOOD DR, Connecticut'
# Status code for '25 DANIEL RD, Connecticut': 200
# Status code for '10 WESTLAND ST, Connecticut': 200
# Status code for '194 KYLES WAY, Connecticut': 200
# Status code for '214 MIRRA DR, Connecticut': 200
# Status code for '61 COURT D APT 61 BLDG 28, Connecticut': 200
# No results for '61 COURT D APT 61 BLDG 28, Connecticut'
# Status code for '115 NEWBERRY RD, Connecticut': 200
# Status code for '68 MAPLE RIDGE DR, Connecticut': 200
# Status code for '0 NORMAN HILL RD, Connecticut': 200
# Status code for '47 RICHARDSON HILL RD, Connecticut': 200
# Status code for '30 BLOCK FARM RD, Connecticut': 200
# Status code for '162 SYLVAN KNOLL ROAD, Connecticut': 200
# Status code for '6 LATIMER LANE, Connecticut': 200
# Status code for '52 SALEM ROAD, Connecticut': 200
# Status code for '40 THIRD ST, Connecticut': 200
# Status code for '21 DOANE RD, Connecticut': 200
# Status code for '48 GRAVELINE AVE, Connecticut': 200
# Status code for '45 STEVENS ST, Connecticut': 200
# Status code for '56 PEMBROKE RD #3, Connecticut': 200
# No results for '56 PEMBROKE RD #3, Connecticut'
# Status code for '30 ROSELEAH DR, Connecticut': 200
# Status code for '27 PUTNAM LANE, Connecticut': 200
# Status code for '205 STERLING ROAD, Connecticut': 200
# Status code for 'BABCOCK HILL RD, Connecticut': 200
# Status code for '20 SOUTH MAIN ST, Connecticut': 200
# Status code for '33 HILLANDALE RD, Connecticut': 200
# Status code for '49 CEDAR SPRING ROAD, Connecticut': 200
# Status code for '21 TALL TIMBERS DR, Connecticut': 200
# Status code for '12 BOULEVARD DR #183, Connecticut': 200
# Status code for '10 WOODLAND LN, Connecticut': 200
# Status code for '881 WHALLEY AV, Connecticut': 200
# Status code for '9 KEOFFERAM RD, Connecticut': 200
# No results for '9 KEOFFERAM RD, Connecticut'
# Status code for '66 BROAD ST, Connecticut': 200
# Status code for '128 MEADOW HILL DR, Connecticut': 200
# No results for '128 MEADOW HILL DR, Connecticut'
# Status code for '419 NEW LONDON RD, Connecticut': 200
# Status code for '105 FEATHER LANE, Connecticut': 200
# Status code for '34 MALLARD COVE & GAR, Connecticut': 200
# No results for '34 MALLARD COVE & GAR, Connecticut'
# Status code for '38 CAMPFIELD DRIVE, Connecticut': 200
# Status code for '75 TRAILSIDE DR, Connecticut': 200
# Status code for '127 STONY HILL RD, Connecticut': 200
# Status code for '9 WINTHROP DR, Connecticut': 200
# Status code for '234 BUTTS BRIDGE RD, Connecticut': 200
# Status code for '39 NORTH ST, Connecticut': 200
# Status code for '500 MAIN ST UNIT 13, Connecticut': 200
# Status code for '110 PARK TERR AVE, Connecticut': 200
# Status code for '94 MULBERRY STREET, Connecticut': 200
# Status code for '142 CENTERBROOK RD, Connecticut': 200
# Status code for '94 HENRY STREET, Connecticut': 200
# Status code for '26 KENYON PL, Connecticut': 200
# Status code for '6 RICKWOOD LN, Connecticut': 200
# Status code for '392 LITCHFIELD RD, Connecticut': 200
# Status code for '366 SIGOURNEY ST, Connecticut': 200
# Status code for '354 BOSTON POST RD, Connecticut': 200
# Status code for '25 KNOLLWOOD DR, Connecticut': 200
# Status code for '251 JOAN DRIVE, Connecticut': 200
# Status code for '31 WOODLAND ROAD, Connecticut': 200
# Status code for '1306 SUMMER HILL DR, Connecticut': 200
# Status code for '26 LIBERTY ST, Connecticut': 200
# Status code for '99 JUPITER POINT RD, Connecticut': 200
# Status code for '25 LINDEN PL, Connecticut': 200
# Status code for '94 MCGUINNESS ST, Connecticut': 200
# Status code for '61-63 WALNUT HILL RD, Connecticut': 200
# Status code for '334 RYE ST, Connecticut': 200
# Status code for '637 COVE ROAD UNIT D19, Connecticut': 200
# No results for '637 COVE ROAD UNIT D19, Connecticut'
# Status code for '104 COUNTY ROAD, Connecticut': 200
# Status code for '274 BROAD BROOK RD, Connecticut': 200
# Status code for '10 WOODLAND PARK, Connecticut': 200
# Status code for '56 BEACON VIEW DRIVE, Connecticut': 200
# Status code for '43 CROSBY STREET, Connecticut': 200
# Status code for '130 MOTT HILL RD, Connecticut': 200
# Status code for '118 MONROE ST, Connecticut': 200
# Status code for '17 WESTLEDGE TER, Connecticut': 200
# Status code for '12 MANCHESTER HEIGTS, Connecticut': 200
# No results for '12 MANCHESTER HEIGTS, Connecticut'
# Status code for '3845 PARK AVENUE #15, Connecticut': 200
# Status code for '73 TRANQUILITY DRIVE, Connecticut': 200
# Status code for '8 SOUTH RD, Connecticut': 200
# Status code for '388R COLONEL LEDYARD HWY, Connecticut': 200
# Status code for '23 BLUEBERRY LN, Connecticut': 200
# Status code for '36 BISHOP ROAD, Connecticut': 200
# Status code for '17-21 RIVERCLIFF DR, Connecticut': 200
# Status code for '485-C HIGH ST, Connecticut': 200
# Status code for '15 RIVER CAMP DR, Connecticut': 200
# Status code for '15 ALBION AVE, Connecticut': 200
# Status code for '229 OLD NEW LONDON RD, Connecticut': 200
# Status code for '288 OXOBOXO DAM RD, Connecticut': 200
# Status code for '166 GULF ST, Connecticut': 200
# Status code for '20 KENDALL GREEN DR, Connecticut': 200
# Status code for '993 YALE AVE, Connecticut': 200
# Status code for '70 BREAULT, Connecticut': 200
# Status code for '194 AMES HOLLOW RD, Connecticut': 200
# Status code for '616 A HERITAGE VILLAGE, Connecticut': 200
# Status code for '15 VINE ST, Connecticut': 200
# Status code for '17 BARRY DR, Connecticut': 200
# Status code for '52 OLD MILL LANE, Connecticut': 200
# Status code for '273 CHURCH ST, Connecticut': 200
# Status code for '1120 RT 171, Connecticut': 200
# Status code for '100 MARK LANE #J5, Connecticut': 200
# No results for '100 MARK LANE #J5, Connecticut'
# Status code for '109 MEADOWS END RD, Connecticut': 200
# Status code for '310 LIGHTHOUSE RD, Connecticut': 200
# Status code for '39 ROSEDALE ROAD, Connecticut': 200
# Status code for '268 MOUNTAIN RD, Connecticut': 200
# Status code for '55 BOTSFORD AVE, Connecticut': 200
# Status code for '450 SPENCER PLAINS RD #3, Connecticut': 200
# No results for '450 SPENCER PLAINS RD #3, Connecticut'
# Status code for '38 BOLTON BRANCH RD, Connecticut': 200
# Status code for '2 LONGRIDGE COURT, Connecticut': 200
# Status code for '471 MAIN ST, Connecticut': 200
# Status code for '163 GOLDEN HILL ST, Connecticut': 200
# Status code for '184 LARRABEE ST, Connecticut': 200
# Status code for '52 HARRISON DRIVE, Connecticut': 200
# Status code for '402 DENISON HL, Connecticut': 200
# Status code for '20 WAVERLY DR, Connecticut': 200
# Status code for '154 A HERITAGE VILLAGE, Connecticut': 200
# Status code for '176 RIDGE PARK AVENUE, Connecticut': 200
# Status code for '111 MILLBROOK DR, Connecticut': 200
# Status code for '118 ROCK HOUSE ROAD, Connecticut': 200
# Status code for '61 HACKETT AVE, Connecticut': 200
# Status code for '900 MIX AVE U22, Connecticut': 200
# No results for '900 MIX AVE U22, Connecticut'
# Status code for '10 DEERFIELD DR, Connecticut': 200
# Status code for '18 GRANT ST, Connecticut': 200
# Status code for '386 HAZARD AVE, Connecticut': 200
# Status code for '5 SEVENTH AVE, Connecticut': 200
# Status code for '28 ARMSTRONG RD A1, Connecticut': 200
# No results for '28 ARMSTRONG RD A1, Connecticut'
# Status code for '22 RICHARD ST, Connecticut': 200
# Status code for '179 & 0 NETTLETON AVE, Connecticut': 200
# Status code for '56 WESTERLY STREET, Connecticut': 200
# Status code for '7 PHILLIPS ST, Connecticut': 200
# Status code for '192 RICHMOND HILL AVENUE #11, Connecticut': 200
# No results for '192 RICHMOND HILL AVENUE #11, Connecticut'
# Status code for '14 SAXTON LN, Connecticut': 200
# Status code for '144 GEORGETOWN DR, Connecticut': 200
# Status code for '124 THOMAS ST + 43 WASHINGTON, Connecticut': 200
# No results for '124 THOMAS ST + 43 WASHINGTON, Connecticut'
# Status code for '60 CONCORD ST, Connecticut': 200
# Status code for '436 LENOX ROAD, Connecticut': 200
# Status code for '182 HIGHLAND AVE, Connecticut': 200
# Status code for '200 BARTON ST, Connecticut': 200
# Status code for '118 EUCLID AVENUE, Connecticut': 200
# Status code for '197 KIMBERLY AVE, Connecticut': 200
# Status code for '4 NORTH LEE RD, Connecticut': 200
# Status code for '10 SPRUCE PEAK LA, Connecticut': 200
# Status code for '101SUNSET DR, Connecticut': 200
# No results for '101SUNSET DR, Connecticut'
# Status code for '15 PIERPONT CT, Connecticut': 200
# Status code for '1 CANTERBURY RD U1, Connecticut': 200
# No results for '1 CANTERBURY RD U1, Connecticut'
# Status code for '9 BLUE HERON LN, Connecticut': 200
# Status code for '49 ERIN DR, Connecticut': 200
# Status code for '110 FERNCLIFF DRIVE, Connecticut': 200
# Status code for '467 SOUNDVIEW AVE, Connecticut': 200
# Status code for '109 PUTTER DR, Connecticut': 200
# Status code for '17 JAMES ST, Connecticut': 200
# Status code for '568 WILSON STREET, Connecticut': 200
# Status code for '26 MARVIN ST, Connecticut': 200
# Status code for '27-25 HILLSIDE PL, Connecticut': 200
# Status code for '319 COTTON HILL ROAD, Connecticut': 200
# Status code for '95 OAK ST, Connecticut': 200
# Status code for '146 ATKINS ST, Connecticut': 200
# Status code for '40 LAKEWOOD CIR NORTH, Connecticut': 200
# Status code for '42 WEDGEWOOD DR, Connecticut': 200
# Status code for '56 TOWNSEND AV, Connecticut': 200
# Status code for '10 WIMBLEDON LANE, Connecticut': 200
# Status code for '544 PROSPECT AVE, Connecticut': 200
# Status code for '615 BROOKSIDE COURT, Connecticut': 200
# Status code for '97 W MAIN ST  #75, Connecticut': 200
# Status code for '184 HAVERFORD ST, Connecticut': 200
# Status code for '1 PLAIN HILL RD, Connecticut': 200
# Status code for '65 WATER ST, Connecticut': 200
# Status code for '8 TOM RD, Connecticut': 200
# Status code for '18 OLD WOOD RD, Connecticut': 200
# Status code for '6 MELISSA WAY, Connecticut': 200
# Status code for '46 PLINY ST, Connecticut': 200
# Status code for '745 MERROW RD #184, Connecticut': 200
# Status code for '38 LEDGER ST, Connecticut': 200
# Status code for '37 MARTIN RD, Connecticut': 200
# Status code for '7 DENISON CT, Connecticut': 200
# Status code for '330 MAIN ST, Connecticut': 200
# Status code for '9 PLYMOUTH AVE, Connecticut': 200
# Status code for '89 WILSON AVE, Connecticut': 200
# Status code for '705 WOODTICK RD, Connecticut': 200
# Status code for '601 SANDSTONE DR, Connecticut': 200
# Status code for '27 MCELANEY DR, Connecticut': 200
# Status code for '82 MIDDLEBROOK ROAD, Connecticut': 200
# Status code for '79 KENSINGTON RD, Connecticut': 200
# Status code for '6 FAWN RIDGE, Connecticut': 200
# Status code for '85 MIDDLEFIELD ST, Connecticut': 200
# Status code for '85 GOSPEL LANE, Connecticut': 200
# Status code for '47 STONE HOUSE LANE, Connecticut': 200
# Status code for '41 LEDGE RD, Connecticut': 200
# Status code for '10 BIRCH ST, Connecticut': 200
# Status code for '25 QUARRY KNOLL CIR, Connecticut': 200
# Status code for '65 PARK RD, Connecticut': 200
# Status code for '631 MIDDLETOWN AV, Connecticut': 200
# Status code for '42 METACOMET RD, Connecticut': 200
# Status code for '5 MANHATTAN RD, Connecticut': 200
# Status code for '284 BARSTOW RD, Connecticut': 200
# Status code for '26 LANDERS RD, Connecticut': 200
# Status code for '5 GLEN RD, Connecticut': 200
# Status code for '69 BEACH DR, Connecticut': 200
# Status code for '95 CHAMBERS STREET, Connecticut': 200
# Status code for '181 EAST ROBBINS AVE, Connecticut': 200
# Status code for '379 WHITFIELD ST BN2638, Connecticut': 200
# No results for '379 WHITFIELD ST BN2638, Connecticut'
# Status code for '106 ASPETUCK VILLAGE, Connecticut': 200
# Status code for '24 FERN DR, Connecticut': 200
# Status code for '662 KENT RD, Connecticut': 200
# Status code for '32 BEACON HILL DR, Connecticut': 200
# Status code for '206 BOURBON ST, Connecticut': 200
# Status code for '27 HAMILTON ST, Connecticut': 200
# Status code for '35 LAFAYETTE AVE, Connecticut': 200
# Status code for '6 ROBERTS RD, Connecticut': 200
# Status code for '126 HOPMEADOW STREET 9B, Connecticut': 200
# No results for '126 HOPMEADOW STREET 9B, Connecticut'
# Status code for '300 BURRITT ST, Connecticut': 200
# Status code for '20A OAKLAND AVE 1A, Connecticut': 200
# No results for '20A OAKLAND AVE 1A, Connecticut'
# Status code for '56 SANDY BROOK DR, Connecticut': 200
# Status code for '321 REID STREET, Connecticut': 200
# Status code for '4 DEERFIELD DR, Connecticut': 200
# Status code for '16 GILES AVE, Connecticut': 200
# Status code for '365 HANOVER ST, Connecticut': 200
# Status code for '675 MIGEON AVE, Connecticut': 200
# Status code for '6 SPRINGDALE AVE, Connecticut': 200
# Status code for '31 DEER RUN LANDING, Connecticut': 200
# No results for '31 DEER RUN LANDING, Connecticut'
# Status code for '502 THAMES ST, Connecticut': 200
# Status code for '157 LEEDER HILL DR U205, Connecticut': 200
# Status code for '32 ROXBURY RD, Connecticut': 200
# Status code for '52 COVENTRY ROAD, Connecticut': 200
# Status code for '14 WHORTLEBERRY RD, Connecticut': 200
# Status code for '555 OLD NORTHFIELD RD, Connecticut': 200
# Status code for '9 POND ST, Connecticut': 200
# Status code for '63 BELLEVUE ST, Connecticut': 200
# Status code for '2 WOLF RIDGE GAP, Connecticut': 200
# Status code for '12-3 CANTERBURY LN, Connecticut': 200
# Status code for '181 HOLLAND LN, Connecticut': 200
# Status code for '88 WINDERMERE VILLAGE RD, Connecticut': 200
# Status code for '393 HOBART ST, Connecticut': 200
# Status code for '17 COWPEN RD, Connecticut': 200
# Status code for '57 HEATHERWOOD DR, Connecticut': 200
# Status code for '112 DEMING ST UNIT A, Connecticut': 200
# No results for '112 DEMING ST UNIT A, Connecticut'
# Status code for '20 SYLVIA DR, Connecticut': 200
# Status code for '72 EASTON AVE, Connecticut': 200
# Status code for '59 DOANE STREET, Connecticut': 200
# Status code for '42 RICHMOND DRIVE, Connecticut': 200
# Status code for '1 BROAD STREET # 20E, Connecticut': 200
# Status code for '55 ASPETUCK VILLAGE, Connecticut': 200
# Status code for '412 ATRIUM, Connecticut': 200
# Status code for '420 HARTFORD RD, Connecticut': 200
# Status code for '129 S EAGLE ST, Connecticut': 200
# Status code for '124 HANOVER-VERSAILLES RD, Connecticut': 200
# Status code for '57 CYPRESS DRIVE, Connecticut': 200
# Status code for '45 HOPE ST  #9, Connecticut': 200
# No results for '45 HOPE ST  #9, Connecticut'
# Status code for '101 LEWIS ST B, Connecticut': 200
# Status code for '847 STERLING RD, Connecticut': 200
# Status code for '21 S EAGLE ST, Connecticut': 200
# Status code for '13 BRADWAY POND RD, Connecticut': 200
# Status code for '30 ALDEN AV, Connecticut': 200
# Status code for '3 CORNELL CT, Connecticut': 200
# Status code for '24 BENSTONE STREET, Connecticut': 200
# Status code for '22 REK LN, Connecticut': 200
# Status code for '204 DOGWOOD LANE, Connecticut': 200
# Status code for '15 HERITAGE FARM ROAD, Connecticut': 200
# No results for '15 HERITAGE FARM ROAD, Connecticut'
# Status code for '41 POPE ST, Connecticut': 200
# Status code for '16 WOODCREST  AVE, Connecticut': 200
# Status code for '31 HEMLOCK DR, Connecticut': 200
# Status code for '36 KENDALL GREEN DR, Connecticut': 200
# Status code for '90 PIEDMONT ST, Connecticut': 200
# Status code for '280 LYME ST, Connecticut': 200
# Status code for '4 FINNEY LANE # 49, Connecticut': 200
# No results for '4 FINNEY LANE # 49, Connecticut'
# Status code for 'MILLBROOK RD, Connecticut': 200
# Status code for '56 WILDCAT RD, Connecticut': 200
# Status code for '495 GOLD STAR HWY STE 211, Connecticut': 200
# No results for '495 GOLD STAR HWY STE 211, Connecticut'
# Status code for '60 CHARTER OAK AVE, Connecticut': 200
# Status code for '52 BLUEBERRY HILL RESERVE, Connecticut': 200
# Status code for '52 SHINGLE MILL RD, Connecticut': 200
# Status code for '350 CANTERBURY ROAD, Connecticut': 200
# Status code for '44 HILLDALE ROAD, Connecticut': 200
# Status code for '3 HOLSTEIN LANE, Connecticut': 200
# Status code for '6 WILDCAT DR, Connecticut': 200
# Status code for '187 COLONIAL RD, Connecticut': 200
# Status code for '25 KENDALL GREEN DR, Connecticut': 200
# Status code for '104 WESTERLEIGH RD, Connecticut': 200
# Status code for '16 LAKEVIEW CIRCLE, Connecticut': 200
# Status code for '32 WINDMILL DR, Connecticut': 200
# No results for '32 WINDMILL DR, Connecticut'
# Status code for '182 BLUFF VIEW DR, Connecticut': 200
# Status code for '64 NICOLE CT, Connecticut': 200
# Status code for '4 KNOLL AVE, Connecticut': 200
# Status code for '20 BARBARA LANE, Connecticut': 200
# Status code for '41 SUNNYSLOPE DR, Connecticut': 200
# Status code for '22 YORKSHIRE COURT, Connecticut': 200
# Status code for '558 PUMPKIN HILL RD, Connecticut': 200
# Status code for '101 OAK ST, Connecticut': 200
# Status code for '193 INDIGO ST, Connecticut': 200
# Status code for '2767 TORRINGFORD W ST, Connecticut': 200
# Status code for '4 LIBERTY LN, Connecticut': 200
# Status code for '140 THOMPSON ST #23H, Connecticut': 200
# Status code for '4 IRONWORKS HILL RD, Connecticut': 200
# Status code for '116 CANAAN CT BLDG 83 APT 24, Connecticut': 200
# No results for '116 CANAAN CT BLDG 83 APT 24, Connecticut'
# Status code for '56 RAYMOND ST, Connecticut': 200
# Status code for '44 BROADWAY N, Connecticut': 200
# Status code for '22 MARITA DR, Connecticut': 200
# Status code for '517 MAIN ST, Connecticut': 200
# Status code for '97 MORGAN AVE, Connecticut': 200
# Status code for '79 SUNNYSIDE DR, Connecticut': 200
# Status code for '22 MALLARD CIRCLE, Connecticut': 200
# Status code for '675 TOWNSEND AV #167, Connecticut': 200
# Status code for '64 SUMMERWOOD DR, Connecticut': 200
# No results for '64 SUMMERWOOD DR, Connecticut'
# Status code for '84 EASTBURY HILL DR, Connecticut': 200
# Status code for '8 LINDA LANE, Connecticut': 200
# Status code for '20 SHAGBARK RD, Connecticut': 200
# Status code for '35 BUELL HILL ROAD, Connecticut': 200
# Status code for '66 COOPER AVE, Connecticut': 200
# Status code for '26 KENMORE LN, Connecticut': 200
# Status code for '79 RIDGEWOOD ROAD, Connecticut': 200
# Status code for '32 COLONIAL DR, Connecticut': 200
# Status code for '430 SQUAW ROCK RD, Connecticut': 200
# Status code for '161 SKYVIEW DR UNIT M-8, Connecticut': 200
# No results for '161 SKYVIEW DR UNIT M-8, Connecticut'
# Status code for '73 STANWOOD DR, Connecticut': 200
# Status code for '12 PARK PL, Connecticut': 200
# Status code for '86 ABBOTSFORD AVENUE, Connecticut': 200
# Status code for '25 EDGEMARTH HILL ROAD, Connecticut': 200
# Status code for '101 CHERRY CIR, Connecticut': 200
# Status code for '420 MILFORD POINT RD, Connecticut': 200
# Status code for '1006 BRIAR WOODS LA, Connecticut': 200
# Status code for '103 VIRGINIA LANE, Connecticut': 200
# Status code for '17 KELLY COURT, Connecticut': 200
# Status code for '15 JONES HOLLOW RD, Connecticut': 200
# Status code for '301 QUARRY ROAD, Connecticut': 200
# Status code for '103 OLCOTT WAY, Connecticut': 200
# Status code for '15 FORDYCE COURT RD #10, Connecticut': 200
# Status code for '63 BAYBERRY RD, Connecticut': 200
# Status code for '62 SHEEPHILL RD, Connecticut': 200
# No results for '62 SHEEPHILL RD, Connecticut'
# Status code for '60 ACKLEY CEMETERY RD, Connecticut': 200
# Status code for '1 SAMPSON STREET, Connecticut': 200
# Status code for '217D WINDGATE CIR, Connecticut': 200
# ...
# Weather API status for lat=41.4393124, lon=-73.2420445, date=2019-04-01: 200
# Weather API status for lat=41.3151001, lon=-73.5363621, date=2019-04-08: 200
# Weather API status for lat=41.6679345, lon=-71.8990736, date=2019-04-08: 200
# Weather API status for lat=41.675074, lon=-71.9186642, date=2019-04-01: 200
# Weather API status for lat=41.25947, lon=-73.4906, date=2019-04-15: 200
# Weather API status for lat=41.81147, lon=-73.0902, date=2019-04-01: 200
# Weather API status for lat=41.8628101, lon=-73.0657109, date=2019-04-15: 200
# Weather API status for lat=41.7176062, lon=-72.6701632, date=2019-04-15: 200
# Weather API status for lat=41.2626827, lon=-72.9449132, date=2019-04-29: 200
# Weather API status for lat=41.8619648, lon=-72.8111534, date=2019-04-22: 200
# Weather API status for lat=41.6955268, lon=-73.0510404, date=2019-04-08: 200
# Weather API status for lat=41.72017, lon=-71.87572, date=2019-04-08: 200
# Weather API status for lat=41.4523265, lon=-72.2375437, date=2019-04-29: 200
# Weather API status for lat=41.5764606, lon=-72.8439073, date=2019-04-15: 200
# Weather API status for lat=41.97689, lon=-72.44733, date=2019-04-15: 200
# Weather API status for lat=41.8737917, lon=-72.7883515, date=2019-04-22: 200
# Weather API status for lat=41.2408399, lon=-73.1344624, date=2019-04-29: 200
# Weather API status for lat=41.2564033, lon=-73.1071416, date=2019-04-01: 200
# Weather API status for lat=41.4483931, lon=-72.8327131, date=2019-04-01: 200
# Weather API status for lat=41.76337, lon=-72.73618, date=2019-04-01: 200
# Weather API status for lat=41.3125679, lon=-72.7765522, date=2019-04-15: 200
# Weather API status for lat=41.9084513, lon=-71.9330621, date=2019-04-15: 200
# Weather API status for lat=41.29309, lon=-73.50454, date=2019-04-15: 200
# Weather API status for lat=41.0811765, lon=-73.5386632, date=2019-04-22: 200
# Weather API status for lat=41.535558, lon=-73.050224, date=2019-04-15: 200
# Weather API status for lat=41.8236105, lon=-72.678024, date=2019-04-01: 200
# Weather API status for lat=41.3535013, lon=-72.931949, date=2019-04-15: 200
# Weather API status for lat=41.5638254, lon=-72.6560926, date=2019-04-08: 200
# Weather API status for lat=41.35234, lon=-73.11976, date=2019-04-22: 200
# Weather API status for lat=41.48801, lon=-73.20396, date=2019-04-22: 200
# Weather API status for lat=41.3162, lon=-73.11348, date=2019-04-15: 200
# Weather API status for lat=41.84146, lon=-72.46952, date=2019-04-22: 200
# Weather API status for lat=41.2971, lon=-72.95919, date=2019-04-01: 200
# Weather API status for lat=41.804916, lon=-73.109221, date=2019-04-22: 200
# Weather API status for lat=41.5069351, lon=-73.2410454, date=2019-04-01: 200
# Weather API status for lat=41.25724, lon=-73.2263667, date=2019-04-22: 200
# Weather API status for lat=41.5792308, lon=-72.7001325, date=2019-04-15: 200
# Weather API status for lat=41.44698, lon=-72.79927, date=2019-04-08: 200
# Weather API status for lat=41.3136374, lon=-72.1318458, date=2019-04-15: 200
# Weather API status for lat=41.54657, lon=-73.05242, date=2019-04-29: 200
# Weather API status for lat=41.2901436, lon=-73.0955673, date=2019-04-22: 200
# Weather API status for lat=41.2846502, lon=-72.8860543, date=2019-04-22: 200
# Weather API status for lat=41.0596462, lon=-73.5323828, date=2019-04-29: 200
# Weather API status for lat=41.6921541, lon=-72.8086447, date=2019-04-01: 200
# Weather API status for lat=41.7489694, lon=-72.7496059, date=2019-04-29: 200
# Weather API status for lat=41.87781, lon=-72.40491, date=2019-04-08: 200
# Weather API status for lat=41.7531676, lon=-72.7347056, date=2019-04-15: 200
# Weather API status for lat=41.097044, lon=-73.527739, date=2019-04-22: 200
# Weather API status for lat=41.7746396, lon=-72.5504146, date=2019-04-08: 200
# Weather API status for lat=41.17001, lon=-73.3273, date=2019-04-15: 200
# Weather API status for lat=41.0411477, lon=-73.5157434, date=2019-04-01: 200
# Weather API status for lat=41.87289, lon=-72.82709, date=2019-04-22: 200
# Weather API status for lat=41.8645372, lon=-72.7932792, date=2019-04-15: 200
# Weather API status for lat=41.3704536, lon=-72.1258942, date=2019-04-15: 200
# Weather API status for lat=41.05428, lon=-73.53612, date=2019-04-01: 200
# Weather API status for lat=41.3570187, lon=-73.1152823, date=2019-04-08: 200
# Weather API status for lat=41.7241, lon=-72.75327, date=2019-04-29: 200
# Weather API status for lat=41.847733, lon=-72.6671855, date=2019-04-08: 200
# Weather API status for lat=41.3347469, lon=-73.3439685, date=2019-04-15: 200
# Weather API status for lat=41.5308767, lon=-73.0322559, date=2019-04-01: 200
# Weather API status for lat=41.80098, lon=-73.13297, date=2019-04-22: 200
# Weather API status for lat=41.0733819, lon=-73.5302795, date=2019-04-01: 200
# Weather API status for lat=41.49493, lon=-71.95537, date=2019-04-29: 200
# Weather API status for lat=41.5573247, lon=-73.007915, date=2019-04-22: 200
# Weather API status for lat=41.3577142, lon=-72.9340033, date=2019-04-29: 200
# Weather API status for lat=41.2397564, lon=-72.9863832, date=2019-04-29: 200
# Weather API status for lat=41.7517544, lon=-72.7464802, date=2019-04-22: 200
# Weather API status for lat=41.8527946, lon=-72.4414219, date=2019-04-08: 200
# Weather API status for lat=41.165948, lon=-73.3260206, date=2019-04-29: 200
# Weather API status for lat=41.8484721, lon=-72.4989974, date=2019-04-29: 200
# Weather API status for lat=41.5467719, lon=-73.0051699, date=2019-04-08: 200
# Weather API status for lat=41.6419126, lon=-72.0703667, date=2019-04-01: 200
# Weather API status for lat=41.372491, lon=-73.5318001, date=2019-04-22: 200
# Weather API status for lat=41.9304177, lon=-73.0582422, date=2019-04-15: 200
# Weather API status for lat=41.87715, lon=-73.10685, date=2019-04-29: 200
# Weather API status for lat=41.3339, lon=-71.96325, date=2019-04-08: 200
# Weather API status for lat=41.413364, lon=-73.1380742, date=2019-04-29: 200
# Weather API status for lat=41.3247189, lon=-73.5421161, date=2019-04-08: 200
# Weather API status for lat=41.7009241, lon=-72.7249428, date=2019-04-29: 200
# Weather API status for lat=41.119171, lon=-73.5461483, date=2019-04-01: 200
# Weather API status for lat=41.349425, lon=-73.0392719, date=2019-04-01: 200
# Weather API status for lat=41.8786857, lon=-72.3789739, date=2019-04-08: 200
# Weather API status for lat=41.2917519, lon=-73.3446201, date=2019-04-01: 200
# Weather API status for lat=41.1806306, lon=-73.2080307, date=2019-04-29: 200
# Weather API status for lat=41.2871436, lon=-73.103127, date=2019-04-01: 200
# Weather API status for lat=41.6036329, lon=-71.9864854, date=2019-04-01: 200
# Weather API status for lat=41.7784989, lon=-72.7295667, date=2019-04-29: 200
# Weather API status for lat=41.83239, lon=-72.4717, date=2019-04-01: 200
# Weather API status for lat=41.9960099, lon=-72.4503803, date=2019-04-01: 200
# Weather API status for lat=41.6961025, lon=-73.0476989, date=2019-04-29: 200
# Weather API status for lat=41.8367407, lon=-72.5256339, date=2019-04-22: 200
# Weather API status for lat=41.0380611, lon=-73.5267607, date=2019-04-22: 200
# Weather API status for lat=41.2807951, lon=-73.1859434, date=2019-04-01: 200
# Weather API status for lat=41.56771, lon=-73.06047, date=2019-04-22: 200
# Weather API status for lat=41.3157734, lon=-72.9608199, date=2019-04-01: 200
# Weather API status for lat=41.4756449, lon=-73.176171, date=2019-04-29: 200
# Weather API status for lat=41.6856684, lon=-72.8566777, date=2019-04-22: 200
# Weather API status for lat=41.2905922, lon=-73.1301746, date=2019-04-01: 200
# Weather API status for lat=41.8214257, lon=-73.1026256, date=2019-04-15: 200
# Weather API status for lat=41.2573406, lon=-73.19704, date=2019-04-15: 200
# Weather API status for lat=41.8112777, lon=-73.1040458, date=2019-04-08: 200
# Weather API status for lat=41.4520418, lon=-72.8145642, date=2019-04-01: 200
# Weather API status for lat=41.9268532, lon=-73.0723834, date=2019-04-29: 200
# Weather API status for lat=41.7501233, lon=-72.7541531, date=2019-04-15: 200
# Weather API status for lat=41.528662, lon=-72.7553476, date=2019-04-29: 200
# Weather API status for lat=41.694825, lon=-72.5909909, date=2019-04-29: 200
# Weather API status for lat=41.8350346, lon=-72.5582421, date=2019-04-08: 200
# Weather API status for lat=41.0799742, lon=-73.5357937, date=2019-04-29: 200
# Weather API status for lat=41.7755615, lon=-72.7792926, date=2019-04-08: 200
# Weather API status for lat=41.2702922, lon=-73.2300736, date=2019-04-29: 200
# Weather API status for lat=41.6874298, lon=-73.0252611, date=2019-04-01: 200
# Weather API status for lat=41.4240407, lon=-72.1012696, date=2019-04-01: 200
# Weather API status for lat=41.52281, lon=-73.02079, date=2019-04-01: 200
# Weather API status for lat=41.185766, lon=-73.1346685, date=2019-04-15: 200
# Weather API status for lat=41.2766266, lon=-72.8874573, date=2019-04-01: 200
# Weather API status for lat=41.3499094, lon=-72.9164992, date=2019-04-01: 200
# Weather API status for lat=41.292955, lon=-73.0516978, date=2019-04-08: 200
# Weather API status for lat=41.852529, lon=-72.5549646, date=2019-04-29: 200
# Weather API status for lat=41.714187, lon=-71.8823592, date=2019-04-29: 200
# Weather API status for lat=41.2597962, lon=-73.0428408, date=2019-04-08: 200
# Weather API status for lat=41.7631605, lon=-72.7183949, date=2019-04-08: 200
# Weather API status for lat=41.80887, lon=-72.59604, date=2019-04-22: 200
# Weather API status for lat=41.792198, lon=-72.7163364, date=2019-04-01: 200
# Weather API status for lat=41.0899684, lon=-73.5839766, date=2019-04-01: 200
# Weather API status for lat=41.3461874, lon=-71.8460781, date=2019-04-15: 200
# Weather API status for lat=41.5710655, lon=-72.8638834, date=2019-04-22: 200
# Weather API status for lat=41.8333179, lon=-72.5392247, date=2019-04-15: 200
# Weather API status for lat=41.3894276, lon=-73.0942875, date=2019-04-08: 200
# Weather API status for lat=41.5971183, lon=-72.9965872, date=2019-04-15: 200
# Weather API status for lat=41.6677731, lon=-73.0301204, date=2019-04-29: 200
# Weather API status for lat=41.7582322, lon=-72.2897981, date=2019-04-15: 200
# Weather API status for lat=41.5913881, lon=-73.0025277, date=2019-04-29: 200
# Weather API status for lat=41.5494074, lon=-73.0297874, date=2019-04-08: 200
# Weather API status for lat=41.7952718, lon=-72.7456952, date=2019-04-29: 200
# Weather API status for lat=41.3309647, lon=-73.4872115, date=2019-04-15: 200
# Weather API status for lat=41.7052665, lon=-72.6594084, date=2019-04-29: 200
# Weather API status for lat=41.57274, lon=-72.55954, date=2019-04-01: 200
# Weather API status for lat=41.2976433, lon=-72.9611837, date=2019-04-29: 200
# Weather API status for lat=41.0866727, lon=-73.561281, date=2019-04-01: 200
# Weather API status for lat=41.414276, lon=-73.1418023, date=2019-04-01: 200
# Weather API status for lat=41.7765637, lon=-72.7322628, date=2019-04-29: 200
# Weather API status for lat=41.5748062, lon=-72.6301735, date=2019-04-01: 200
# Weather API status for lat=41.54028, lon=-73.04664, date=2019-04-15: 200
# Weather API status for lat=41.75329, lon=-72.7295148, date=2019-04-01: 200
# Weather API status for lat=41.6141799, lon=-72.6929371, date=2019-04-01: 200
# Weather API status for lat=41.6130924, lon=-72.7225291, date=2019-04-29: 200
# Weather API status for lat=41.6725277, lon=-73.1144895, date=2019-04-01: 200
# Weather API status for lat=42.0082427, lon=-72.3998572, date=2019-04-01: 200
# Final enhanced dataset saved to 'enhanced_real_estate_april_2019.csv'.
#
# First few rows of enhanced data:
#                     Address Date Recorded          Town   Latitude  Longitude  \
# 69711           12 LILAC LA    2019-04-22    Farmington  41.203871 -73.348720
# 69734           626 MAIN ST    2019-04-22    East Haven  41.522659 -72.847268
# 69803          331 LEDGE DR    2019-04-08    Torrington  41.875988 -73.109155
# 876642         6 HICKORY LA    2019-04-01        Bozrah  41.330814 -73.041664
# 876644  44 OLD ELLINGTON RD    2019-04-01  East Windsor  41.910486 -72.556641
#
#        Max_Temperature_C Precipitation_mm
# 69711               17.4             15.6
# 69734               16.5             14.9
# 69803               12.8             10.0
# 876642               6.9              0.0
# 876644               6.5              0.0
#
# Failed addresses: ['135, 137, 139 VALLEY DR', '809 BIRMINGHAM CONDO', '61 COURT D APT 61 BLDG 28 SUCC', '29 JENNING STREET', '19 PINEWOODS LA', '73 RASPBERRY HILL', '170 SO MAIN ST', 'BUILDING 51 APT 401 OF SUCCESS', 'CHAMBERLAIN HWY; 14-1/12/13', '125 OLIVE ST #E-1', '22 GLEN RDIGE CT', '3380 MADISON AVE UNIT 15A', '91 RIVERVIEW RD  #8C', '40 OWEN ST #C-11, D-02, E-2, E', 'CHAMBERLAIN HWY; 13-2/12/10', '1 MAPLE ST #25', '18 STONECLIFFE DR', '128 RESERVIOR AVE', '24 WEST ELM ST 24', 'CHAMBERLAIN HWY; 13-2/12/10', '45 POCONO LANE #10', 'UNIT C-12 RIVER ROAD', '42 CHESTNUT COURT U-48G', '222 WILLIAMS ST E UNIT 406', 'CHAMBERLAIN HWY; 14-1/12/13', '229 ELLINGTON RD UNIT V', '21 BROAD ST EXT', '122 COALPIT HILL RD', '20 VILLAGE CROSSING', '152 ROCKWELL RD A-1', '3225 MADISON AVE UNIT 13', '10 WILLOW SPRINGS', '169 MASON ST 2D', '9 MARLDON RD', '76 QUINEBAUG CAMP RD LOT 8', 'MAPLE AVE MP37 LT 15', '80 PEDDLARS DR', '56 FRANKLIN ST #2-7', '6A MAPLEWOOD CONDO', '5C HARBOUR VILLAGE', '50 LAFAYETTE PL 2F', '76 QUINEBAUG CAMP RD LOT 8', '333 VINCELLETTE ST UNIT 1', '1175 WHITNEY AVE UB-1', '41 CARNOUSTIE CIR', '87 OCONNELL RD EXT', '135 SQUIRREL TR', 'R003 NEWBERRY RD', '102 COMSTOCK TR', '520 VINCELLETTE ST UNIT D-1', '305 EH MOODUS RD', '34 PEDDLARS DR', '18 VAN TASSELL DR', '260 SONTROM RD', '560 NORTH WASHINGTON AVE #06H', '278 SKYVIEW DR U V-6', 'SATANS KINGDOM ROAD', '1 ABBOTT RD #3', '70 RIVERSIDE DR #A13', '11 ROSEMONT DT', '835 LONG HILL RD #B', '15 CHESTNUT COURT U-30A', '154 KINGS HWY UNIT C', '893 FARMINGTON AVENUE UNIT 2-2', '54 ROPE FERRY RD B24 & GAR16', '330 MERWIN AVE #5E', '543 ROPE FERRY RD  D67', '56 LORINGS', '8A 8B 8A-A1 PASCO DR', '34 CRESCENT STREET # 1F', '7 DEAN ST #1-103', '39 CALVIN FRECH RD', '152 ROCKWELL RD A-2', '421 ATLANTIC STREET # ASCAI-3', '44 STRAWBERRY HILL AVE # 12B', '39 SUMMERWOOD DR', '61 COURT D APT 61 BLDG 28', '56 PEMBROKE RD #3', '9 KEOFFERAM RD', '128 MEADOW HILL DR', '34 MALLARD COVE & GAR', '637 COVE ROAD UNIT D19', '12 MANCHESTER HEIGTS', '100 MARK LANE #J5', '450 SPENCER PLAINS RD #3', '900 MIX AVE U22', '28 ARMSTRONG RD A1', '192 RICHMOND HILL AVENUE #11', '124 THOMAS ST + 43 WASHINGTON', '101SUNSET DR', '1 CANTERBURY RD U1', '379 WHITFIELD ST BN2638', '126 HOPMEADOW STREET 9B', '20A OAKLAND AVE 1A', '31 DEER RUN LANDING', '112 DEMING ST UNIT A', '45 HOPE ST  #9', '15 HERITAGE FARM ROAD', '4 FINNEY LANE # 49', '495 GOLD STAR HWY STE 211', '32 WINDMILL DR', '116 CANAAN CT BLDG 83 APT 24', '64 SUMMERWOOD DR', '161 SKYVIEW DR UNIT M-8', '62 SHEEPHILL RD', '267 MELBA ST #A27', '9 OAK BRANCH DR', '146 SPRINGSIDE AV #B10', '2437 BEDFORD STREET # 20-9', '126 QUINEBAUG CAMP ROAD LOT 3', '154 COLD SPRING ROAD # 61', '38 STONE POND DRIVE', '125 BOSTFORD ST', '7 AND 7A COOLEY RD', '19 BAUER PLACE EXT', '37 GREENWICH AVENUE # 1-11B', '2 ANTHONYS LN', '166 OLD BROOKFIELD RD #3A4', '2459 WHITNEY AVE U4', '45 STREAMVIEW CIRCLE', '3 GOLDEN COURT U-64B', '51 SCHUYLER AVE # 5B', '76 THIRD AVE EXT', '14 MOUNTAIN TR', '370 NO SOCIETY RD', '57 NINAS WAY', '10D PILGRIMS HARBOR', '94 LIBERTY STREET # 3', '112 NINTH DISTRICT RD', '51 YALESVILLE SQUARE', '7 JENSEN CT (TP)', '159 COLONIAL ROAD UNIT #19', '135 COURTLAND AVENUE UNIT #20', '27 NORTHILL STREET # 2J', '88 SOKOL RD UNIT 4', '697-04 SOUTH END RD', '1385 HIGHLAND AVE #7B', '118 GROVE STREET # 25', '125 WARNER HILL RD UNIT 39', '4 LOVELAND HILL RD #I4', '211 SEATON ROAD # 25-A2', '0 LAKESHORE BLVD', '3699 BROADBRIDGE AVE UNIT 308', '9 APPLE TREE TERR', '144 BOULDER CREST LN', '236 SEATON ROAD # 29-D2', '396 NORTH WALNUT', '581 HIGHLAND AVE #3', '129 TAFT POINTE #3', '405 ATLANTIC STREET #ASCAI-2', '35 RINGGOLD STREET UNIT 305', '27 NORTHILL STREET #4F', '42 NORTH MAIN STREET UNIT 53', '5 HERITAGE WOODS', '55 WARDWELL STREET UNIT B', '6 FOREST ST (TP)', '404 WOODLAND HILLD DRIVE', '1 BRUSH PASTURE LN UNIT 212', '115 BARROWS T']

# %%
# Step 7: Plot scatterplot
plt.figure(figsize=(10, 6))
plt.scatter(geocoded_data['Longitude'], geocoded_data['Latitude'], s=20, alpha=0.5)
plt.title('Geocoded Real Estate Sales - Mondays in April 2019')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

'''
# Save caches for reuse
with open('geocode_cache.json', 'w') as f:
    json.dump({k: list(v) for k, v in geocode_cache.items()}, f)
with open('weather_cache.json', 'w') as f:
    json.dump({str(k): list(v) for k, v in weather_cache.items()}, f)
'''
# Out:
# "\n# Save caches for reuse\nwith open('geocode_cache.json', 'w') as f:\n    json.dump({k: list(v) for k, v in geocode_cache.items()}, f)\nwith open('weather_cache.json', 'w') as f:\n    json.dump({str(k): list(v) for k, v in weather_cache.items()}, f)\n"
